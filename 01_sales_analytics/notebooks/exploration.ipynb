# %% [markdown]
# # 🔍 Data Exploration
# Basic sanity checks and distributions of the sales dataset.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

df = pd.read_csv('../../shared/data/sales_transactions.csv')
df.head()

# %%
df.info()

# %%
df.describe()
